# %%
import pandas as pd
import numpy as np
import random
import os

from supervised.automl import AutoML

train_df = pd.read_csv("./train.csv")
test_df =  pd.read_csv("./test.csv")

target_columns = train_df.filter(regex="새순").columns
train_df["새순mean"]   = train_df[target_columns].mean(axis=1)
train_df["새순std"]    = train_df[target_columns].std(axis=1)
train_df["새순diff"] = train_df["2022-11-28 새순"] - train_df["2022-09-01 새순"]
train_df["새순min"]    = train_df[target_columns].min(axis=1)
train_df["새순max"]    = train_df[target_columns].max(axis=1)

test_df["새순mean"]   = test_df[target_columns].mean(axis=1)
test_df["새순std"]    = test_df[target_columns].std(axis=1)
test_df["새순diff"]   = test_df["2022-11-28 새순"] - test_df["2022-09-01 새순"]
test_df["새순min"]    = test_df[target_columns].min(axis=1)
test_df["새순max"]    = test_df[target_columns].max(axis=1)

X = train_df[train_df.filter(regex="새순").columns]
print(X.columns)
y = train_df.iloc[:, 1]

automl = AutoML(mode="Compete", eval_metric='mae')
automl.fit(X, y)
pred = automl.predict(test_df[test_df.filter(regex="새순").columns])

submission = pd.read_csv("../data/sample_submission.csv")
submission.iloc[:, 1] = pred
submission.to_csv("automl_fixed.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[10], line 6
#       3 import random
#       4 import os
# ----> 6 from supervised.automl import AutoML
#       8 train_df = pd.read_csv("./train.csv")
#       9 test_df =  pd.read_csv("./test.csv")
#
# File C:\AI\pythonProject\venv\lib\site-packages\supervised\__init__.py:3
#       1 __version__ = "0.11.5"
# ----> 3 from supervised.automl import AutoML
#
# File C:\AI\pythonProject\venv\lib\site-packages\supervised\automl.py:2
#       1 import logging
# ----> 2 from supervised.base_automl import BaseAutoML
#       3 from supervised.utils.config import LOG_LEVEL
#       5 # libraries for type hints
#
# File C:\AI\pythonProject\venv\lib\site-packages\supervised\base_automl.py:21
#      18 from sklearn.utils.validation import check_array
#      19 from sklearn.metrics import r2_score, accuracy_score
# ---> 21 from supervised.algorithms.registry import AlgorithmsRegistry
#      22 from supervised.algorithms.registry import BINARY_CLASSIFICATION
#      23 from supervised.algorithms.registry import MULTICLASS_CLASSIFICATION
#
# File C:\AI\pythonProject\venv\lib\site-packages\supervised\algorithms\registry.py:70
#      66         return automl_eval_metric
#      69 # Import algorithm to be registered
# ---> 70 import supervised.algorithms.random_forest
#      71 import supervised.algorithms.xgboost
#      72 import supervised.algorithms.decision_tree
#
# File C:\AI\pythonProject\venv\lib\site-packages\supervised\algorithms\random_forest.py:8
#       5 from sklearn.ensemble import RandomForestClassifier
#       6 from sklearn.ensemble import RandomForestRegressor
# ----> 8 from supervised.algorithms.algorithm import BaseAlgorithm
#       9 from supervised.algorithms.sklearn import (
#      10     SklearnTreesEnsembleClassifierAlgorithm,
#      11     SklearnTreesEnsembleRegressorAlgorithm,
#      12 )
#      14 from supervised.algorithms.registry import AlgorithmsRegistry
#
# File C:\AI\pythonProject\venv\lib\site-packages\supervised\algorithms\algorithm.py:4
#       2 import numpy as np
#       3 from supervised.utils.importance import PermutationImportance
# ----> 4 from supervised.utils.shap import PlotSHAP
#       5 from supervised.utils.common import construct_learner_name
#       8 class BaseAlgorithm:
#
# File C:\AI\pythonProject\venv\lib\site-packages\supervised\utils\shap.py:13
#       6 from sklearn.preprocessing import OneHotEncoder
#       8 from supervised.algorithms.registry import (
#       9     BINARY_CLASSIFICATION,
#      10     MULTICLASS_CLASSIFICATION,
#      11     REGRESSION,
#      12 )
# ---> 13 import shap
#      16 logger = logging.getLogger(__name__)
#      17 from supervised.utils.config import LOG_LEVEL
#
# File C:\AI\pythonProject\venv\lib\site-packages\shap\__init__.py:12
#       9 if (sys.version_info < (3, 0)):
#      10     warnings.warn("As of version 0.29.0 shap only supports Python 3 (not 2)!")
# ---> 12 from ._explanation import Explanation, Cohorts
#      14 # explainers
#      15 from .explainers._explainer import Explainer
#
# File C:\AI\pythonProject\venv\lib\site-packages\shap\_explanation.py:12
#      10 from slicer import Slicer, Alias, Obj
#      11 # from ._order import Order
# ---> 12 from .utils._general import OpChain
#      13 from .utils._exceptions import DimensionError
#      15 # slicer confuses pylint...
#      16 # pylint: disable=no-member
#
# File C:\AI\pythonProject\venv\lib\site-packages\shap\utils\__init__.py:1
# ----> 1 from ._clustering import hclust_ordering, partition_tree, partition_tree_shuffle, delta_minimization_order, hclust
#       2 from ._general import approximate_interactions, potential_interactions, sample, safe_isinstance, assert_import, record_import_error
#       3 from ._general import shapley_coefficients, convert_name, format_value, ordinal_str, OpChain, suppress_stderr
#
# File C:\AI\pythonProject\venv\lib\site-packages\shap\utils\_clustering.py:4
#       2 import scipy as sp
#       3 from scipy.spatial.distance import pdist
# ----> 4 from numba import jit
#       5 import sklearn
#       6 import warnings
#
# File C:\AI\pythonProject\venv\lib\site-packages\numba\__init__.py:42
#      38 from numba.core.decorators import (cfunc, generated_jit, jit, njit, stencil,
#      39                                    jit_module)
#      41 # Re-export vectorize decorators and the thread layer querying function
# ---> 42 from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#      43                             get_num_threads, set_num_threads,
#      44                             set_parallel_chunksize, get_parallel_chunksize,
#      45                             get_thread_id)
#      47 # Re-export Numpy helpers
#      48 from numba.np.numpy_support import carray, farray, from_dtype
#
# File C:\AI\pythonProject\venv\lib\site-packages\numba\np\ufunc\__init__.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 from numba.np.ufunc.decorators import Vectorize, GUVectorize, vectorize, guvectorize
#       4 from numba.np.ufunc._internal import PyUFunc_None, PyUFunc_Zero, PyUFunc_One
#       5 from numba.np.ufunc import _internal, array_exprs
#
# File C:\AI\pythonProject\venv\lib\site-packages\numba\np\ufunc\decorators.py:3
#       1 import inspect
# ----> 3 from numba.np.ufunc import _internal
#       4 from numba.np.ufunc.parallel import ParallelUFuncBuilder, ParallelGUFuncBuilder
#       6 from numba.core.registry import DelayedRegistry
#
# SystemError: initialization of _internal failed without raising an exception

# %%
# !pip install pycaret
# Out:
# Collecting pycaret
#   Downloading pycaret-2.3.10-py3-none-any.whl (320 kB)
#      ---------------------------------------- 0.0/320.2 kB ? eta -:--:--
#      -------------------------------------- 320.2/320.2 kB 9.7 MB/s eta 0:00:00
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ---------------------------------------- 1.3/1.3 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm>=2.3.1 in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (3.3.5)
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------------- 1.5/1.5 MB 48.4 MB/s eta 0:00:00
# Collecting pyyaml<6.0.0
#   Downloading PyYAML-5.4.1-cp38-cp38-win_amd64.whl (213 kB)
#      ---------------------------------------- 0.0/213.6 kB ? eta -:--:--
#      ---------------------------------------- 213.6/213.6 kB ? eta 0:00:00
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ---------------------------------------- 0.0/56.6 kB ? eta -:--:--
#      ---------------------------------------- 56.6/56.6 kB ? eta 0:00:00
# Collecting pandas-profiling>=2.8.0
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ---------------------------------------- 0.0/324.4 kB ? eta -:--:--
#      ------------------------------------- 324.4/324.4 kB 20.9 MB/s eta 0:00:00
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ---------------------------------------- 0.0/636.8 kB ? eta -:--:--
#      ------------------------------------- 636.8/636.8 kB 41.8 MB/s eta 0:00:00
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: scikit-plot in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: plotly>=4.4.1 in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (5.13.0)
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp38-cp38-win_amd64.whl (31.4 MB)
#      ---------------------------------------- 0.0/31.4 MB ? eta -:--:--
#      ------ -------------------------------- 5.2/31.4 MB 111.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 9.2/31.4 MB 98.8 MB/s eta 0:00:01
#      ------------------ -------------------- 15.1/31.4 MB 93.9 MB/s eta 0:00:01
#      ----------------------- -------------- 19.5/31.4 MB 129.5 MB/s eta 0:00:01
#      ------------------------------- ------- 25.0/31.4 MB 93.9 MB/s eta 0:00:01
#      ---------------------------------- --- 28.8/31.4 MB 110.0 MB/s eta 0:00:01
#      --------------------------------------  31.4/31.4 MB 93.9 MB/s eta 0:00:01
#      --------------------------------------  31.4/31.4 MB 93.9 MB/s eta 0:00:01
#      --------------------------------------- 31.4/31.4 MB 43.7 MB/s eta 0:00:00
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.9-cp38-cp38-win_amd64.whl (9.4 MB)
#      ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#      ------------------ --------------------- 4.4/9.4 MB 93.5 MB/s eta 0:00:01
#      ------------------------------------- -- 8.7/9.4 MB 79.1 MB/s eta 0:00:01
#      ---------------------------------------  9.4/9.4 MB 85.2 MB/s eta 0:00:01
#      ---------------------------------------- 9.4/9.4 MB 59.7 MB/s eta 0:00:00
# Collecting cufflinks>=0.17.0
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ---------------------------------------- 0.0/81.7 kB ? eta -:--:--
#      ---------------------------------------- 81.7/81.7 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting numba<0.55
#   Downloading numba-0.54.1-cp38-cp38-win_amd64.whl (2.3 MB)
#      ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#      ---------------------------------------- 2.3/2.3 MB 48.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (1.2.0)
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3-cp38-cp38-win_amd64.whl (24.2 MB)
#      ---------------------------------------- 0.0/24.2 MB ? eta -:--:--
#      ----- ---------------------------------- 3.5/24.2 MB 56.5 MB/s eta 0:00:01
#      ------------ --------------------------- 7.5/24.2 MB 68.9 MB/s eta 0:00:01
#      -------------------- ------------------ 13.0/24.2 MB 81.8 MB/s eta 0:00:01
#      -------------------------- ------------ 16.5/24.2 MB 93.9 MB/s eta 0:00:01
#      --------------------------------- ----- 20.7/24.2 MB 93.0 MB/s eta 0:00:01
#      --------------------------------------  24.2/24.2 MB 93.0 MB/s eta 0:00:01
#      --------------------------------------  24.2/24.2 MB 93.0 MB/s eta 0:00:01
#      --------------------------------------- 24.2/24.2 MB 50.4 MB/s eta 0:00:00
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#      ---------------------------------------- 0.0/167.1 kB ? eta -:--:--
#      ---------------------------------------- 167.1/167.1 kB ? eta 0:00:00
# Requirement already satisfied: seaborn in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: matplotlib in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (3.6.3)
# Requirement already satisfied: wordcloud in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (1.8.2.2)
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ---------------------------------------- 0.0/282.6 kB ? eta -:--:--
#      ---------------------------------------- 282.6/282.6 kB ? eta 0:00:00
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.0-py3-none-any.whl (2.6 MB)
#      ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#      ---------------------------------------- 2.6/2.6 MB 81.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (1.5.3)
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp38-cp38-win_amd64.whl (6.8 MB)
#      ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#      ---------------------------------------  6.8/6.8 MB 220.0 MB/s eta 0:00:01
#      ---------------------------------------- 6.8/6.8 MB 87.4 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: IPython in c:\ai\pythonproject\venv\lib\site-packages (from pycaret) (8.9.0)
# Collecting pyod
#   Downloading pyod-1.0.8.tar.gz (149 kB)
#      ---------------------------------------- 0.0/150.0 kB ? eta -:--:--
#      ---------------------------------------- 150.0/150.0 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ---------------------------------------- 0.0/88.2 kB ? eta -:--:--
#      ---------------------------------------- 88.2/88.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mlflow
#   Downloading mlflow-2.2.1-py3-none-any.whl (17.6 MB)
#      ---------------------------------------- 0.0/17.6 MB ? eta -:--:--
#      ---------- ----------------------------- 4.5/17.6 MB 98.6 MB/s eta 0:00:01
#      --------------------- ------------------ 9.4/17.6 MB 86.1 MB/s eta 0:00:01
#      ------------------------------- ------- 14.2/17.6 MB 93.9 MB/s eta 0:00:01
#      --------------------------------------  17.6/17.6 MB 93.9 MB/s eta 0:00:01
#      --------------------------------------  17.6/17.6 MB 93.9 MB/s eta 0:00:01
#      --------------------------------------- 17.6/17.6 MB 59.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in c:\ai\pythonproject\venv\lib\site-packages (from imbalanced-learn==0.7.0->pycaret) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\ai\pythonproject\venv\lib\site-packages (from scikit-learn==0.23.2->pycaret) (3.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\ai\pythonproject\venv\lib\site-packages (from cufflinks>=0.17.0->pycaret) (1.16.0)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\ai\pythonproject\venv\lib\site-packages (from cufflinks>=0.17.0->pycaret) (65.5.1)
# Collecting Cython==0.29.14
#   Downloading Cython-0.29.14-cp38-cp38-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 1.7/1.7 MB 55.2 MB/s eta 0:00:00
# Collecting smart-open>=1.8.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#      ---------------------------------------- 56.8/56.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: stack-data in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (0.18.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (3.0.36)
# Requirement already satisfied: pickleshare in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: backcall in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (2.14.0)
# Requirement already satisfied: traitlets>=5 in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (5.9.0)
# Requirement already satisfied: colorama in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (0.4.6)
# Requirement already satisfied: decorator in c:\ai\pythonproject\venv\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\ai\pythonproject\venv\lib\site-packages (from ipywidgets->pycaret) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\ai\pythonproject\venv\lib\site-packages (from ipywidgets->pycaret) (6.21.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\ai\pythonproject\venv\lib\site-packages (from ipywidgets->pycaret) (4.0.5)
# Requirement already satisfied: wheel in c:\ai\pythonproject\venv\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.38.4)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ---------------------------------------- 1.3/1.3 MB 88.9 MB/s eta 0:00:00
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ---------------------------------------- 1.3/1.3 MB 83.6 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\ai\pythonproject\venv\lib\site-packages (from matplotlib->pycaret) (1.0.7)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp38-cp38-win_amd64.whl (17.0 MB)
#      ---------------------------------------- 0.0/17.0 MB ? eta -:--:--
#      ----------- --------------------------- 4.8/17.0 MB 102.2 MB/s eta 0:00:01
#      ---------------------- ---------------- 9.6/17.0 MB 122.9 MB/s eta 0:00:01
#      --------------------------------- ----- 14.6/17.0 MB 93.0 MB/s eta 0:00:01
#      -------------------------------------  17.0/17.0 MB 131.2 MB/s eta 0:00:01
#      -------------------------------------  17.0/17.0 MB 131.2 MB/s eta 0:00:01
#      --------------------------------------- 17.0/17.0 MB 59.8 MB/s eta 0:00:00
# Collecting numpy>=1.13.3
#   Downloading numpy-1.20.3-cp38-cp38-win_amd64.whl (13.7 MB)
#      ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#      ------------- ------------------------- 4.7/13.7 MB 152.6 MB/s eta 0:00:01
#      -------------------------- ------------ 9.4/13.7 MB 120.0 MB/s eta 0:00:01
#      -------------------------------------  13.7/13.7 MB 108.8 MB/s eta 0:00:01
#      --------------------------------------- 13.7/13.7 MB 72.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\ai\pythonproject\venv\lib\site-packages (from pandas->pycaret) (2022.7.1)
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.1.0-py2.py3-none-any.whl (344 kB)
#      ---------------------------------------- 0.0/344.9 kB ? eta -:--:--
#      ---------------------------------------- 344.9/344.9 kB ? eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in c:\ai\pythonproject\venv\lib\site-packages (from plotly>=4.4.1->pycaret) (8.2.1)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp38-cp38-win_amd64.whl (30 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\ai\pythonproject\venv\lib\site-packages (from spacy<2.4.0->pycaret) (2.28.2)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp38-cp38-win_amd64.whl (18 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp38-cp38-win_amd64.whl (96 kB)
#      ---------------------------------------- 0.0/96.7 kB ? eta -:--:--
#      ---------------------------------------- 96.7/96.7 kB ? eta 0:00:00
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\ai\pythonproject\venv\lib\site-packages (from spacy<2.4.0->pycaret) (4.65.0)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.9-cp38-cp38-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#      ----------------------------- ---------- 5.2/7.0 MB 168.8 MB/s eta 0:00:01
#      ---------------------------------------  7.0/7.0 MB 111.3 MB/s eta 0:00:01
#      ---------------------------------------- 7.0/7.0 MB 64.4 MB/s eta 0:00:00
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.6-cp38-cp38-win_amd64.whl (198 kB)
#      ---------------------------------------- 0.0/198.8 kB ? eta -:--:--
#      ---------------------------------------- 198.8/198.8 kB ? eta 0:00:00
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.6-cp38-cp38-win_amd64.whl (831 kB)
#      ---------------------------------------- 0.0/831.4 kB ? eta -:--:--
#      ------------------------------------- 831.4/831.4 kB 51.3 MB/s eta 0:00:00
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
#      ---------------------------------------- 0.0/274.2 kB ? eta -:--:--
#      ---------------------------------------- 274.2/274.2 kB ? eta 0:00:00
#   Downloading yellowbrick-1.3.post1-py3-none-any.whl (271 kB)
#      ---------------------------------------- 0.0/271.4 kB ? eta -:--:--
#      ---------------------------------------- 271.4/271.4 kB ? eta 0:00:00
#   Downloading yellowbrick-1.3-py3-none-any.whl (271 kB)
#      ---------------------------------------- 0.0/271.3 kB ? eta -:--:--
#      ---------------------------------------- 271.3/271.3 kB ? eta 0:00:00
#   Downloading yellowbrick-1.2.1-py3-none-any.whl (269 kB)
#      ---------------------------------------- 0.0/269.5 kB ? eta -:--:--
#      ------------------------------------- 269.5/269.5 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (3.1.2)
# Requirement already satisfied: cloudpickle<3 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (2.2.1)
# Collecting entrypoints<1
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (3.19.6)
# Requirement already satisfied: Flask<3 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (2.2.2)
# Requirement already satisfied: shap<1,>=0.40 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (0.41.0)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      ---------------------------------------- 0.0/147.5 kB ? eta -:--:--
#      ---------------------------------------- 147.5/147.5 kB ? eta 0:00:00
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ---------------------------------------- 0.0/184.3 kB ? eta -:--:--
#      ------------------------------------- 184.3/184.3 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: markdown<4,>=3.3 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (3.4.1)
# Collecting pyarrow<12,>=4.0.0
#   Downloading pyarrow-11.0.0-cp38-cp38-win_amd64.whl (20.6 MB)
#      ---------------------------------------- 0.0/20.6 MB ? eta -:--:--
#      -------- ------------------------------- 4.2/20.6 MB 66.0 MB/s eta 0:00:01
#      ------------------ --------------------- 9.4/20.6 MB 99.6 MB/s eta 0:00:01
#      --------------------------- ---------- 15.0/20.6 MB 131.2 MB/s eta 0:00:01
#      -------------------------------------  20.6/20.6 MB 110.0 MB/s eta 0:00:01
#      -------------------------------------  20.6/20.6 MB 110.0 MB/s eta 0:00:01
#      --------------------------------------- 20.6/20.6 MB 59.4 MB/s eta 0:00:00
# Collecting waitress<3
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: alembic<2 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (1.10.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (2.0.4)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (6.0.0)
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.5.tar.gz (82 kB)
#      ---------------------------------------- 0.0/82.4 kB ? eta -:--:--
#      ---------------------------------------- 82.4/82.4 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: click<9,>=7.0 in c:\ai\pythonproject\venv\lib\site-packages (from mlflow->pycaret) (8.1.3)
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 0.0/42.8 kB ? eta -:--:--
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2022.10.31-cp38-cp38-win_amd64.whl (267 kB)
#      ---------------------------------------- 0.0/267.7 kB ? eta -:--:--
#      ------------------------------------- 267.7/267.7 kB 17.2 MB/s eta 0:00:00
# Collecting funcy
#   Downloading funcy-1.18-py2.py3-none-any.whl (33 kB)
# Collecting numexpr
#   Downloading numexpr-2.8.4-cp38-cp38-win_amd64.whl (92 kB)
#      ---------------------------------------- 0.0/92.7 kB ? eta -:--:--
#      ---------------------------------------- 92.7/92.7 kB 5.2 MB/s eta 0:00:00
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 1.7/1.7 MB 53.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting sklearn
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#
#   If the previous advice does not cover your use case, feel free to report it at
#   https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
